# %%
from asyncio.windows_events import NULL

import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'D:\Projects\Sarkari-Sahayak\data\updated_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3400 entries, 0 to 3399
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   scheme_name     3400 non-null   str
#  1   slug            3400 non-null   str
#  2   details         3400 non-null   str
#  3   benefits        3400 non-null   str
#  4   eligibility     3400 non-null   str
#  5   application     3398 non-null   str
#  6   documents       3389 non-null   str
#  7   level           3400 non-null   str
#  8   schemeCategory  3400 non-null   str
#  9   Unnamed: 9      0 non-null      float64
#  10  tags            3371 non-null   str
# dtypes: float64(1), str(10)
# memory usage: 12.5 MB

# %%
df = df.dropna(subset=["application", "documents"])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 3387 entries, 0 to 3399
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   scheme_name     3387 non-null   str
#  1   slug            3387 non-null   str
#  2   details         3387 non-null   str
#  3   benefits        3387 non-null   str
#  4   eligibility     3387 non-null   str
#  5   application     3387 non-null   str
#  6   documents       3387 non-null   str
#  7   level           3387 non-null   str
#  8   schemeCategory  3387 non-null   str
#  9   Unnamed: 9      0 non-null      float64
#  10  tags            3359 non-null   str
# dtypes: float64(1), str(10)
# memory usage: 12.4 MB

# %%
df.head(5)
# Out:
#                                          scheme_name               slug  \
# 0  "Immediate Relief Assistance" under "Welfare a...       ira-wrflsncs
# 1  AICTE SHORT TERM TRAINING PROGRAMME-SFURTI SCHEME             astpss
# 2  Burial and Ex-gratia Payment Scheme in Case of...  baepsicodouldwact
# 3                Consortia & Tender Marketing Scheme               ctms
# 4                  Garuda Scheme for Funeral Expense               gsfe
#
#                                              details  \
# 0  The scheme "Immediate Relief Assistance" is a ...
# 1  Short Term Training Programme-SFURTI Program, ...
# 2  Launched in 2014, the " Burial and Ex-gratia P...
# 3  Promotion of the product of Micro and Small En...
# 4  Andhra Pradesh Brahmin Welfare Corporation (AB...
#
#                                             benefits  \
# 0  ₹ 1,00,000, in two installments of ₹ 50,000 ea...
# 1  Financial Assistance : Limit of funding ₹ 4,00...
# ...

# %%
df = df.drop(columns=['Unnamed: 9'])

# %%
df
# Out:
#                                             scheme_name               slug  \
# 0     "Immediate Relief Assistance" under "Welfare a...       ira-wrflsncs
# 1     AICTE SHORT TERM TRAINING PROGRAMME-SFURTI SCHEME             astpss
# 2     Burial and Ex-gratia Payment Scheme in Case of...  baepsicodouldwact
# 3                   Consortia & Tender Marketing Scheme               ctms
# 4                     Garuda Scheme for Funeral Expense               gsfe
# ...                                                 ...                ...
# 3395  “Ishan Uday” Special Scholarship Scheme For No...         iu-sss-ner
# 3396  “Medical Camps (Allopathy and Indian systems o...    mcacism-giapsca
# 3397                         “RAKSHAK PURASKARS’’ Award                rpa
# 3398  “Training in Coir” Component of the "Developme...         ticcotdocs
# 3399                ₹ 5 Lakh Insurance Cover To Farmers   farmer-insurance
#
#                                                 details  \
# ...

# %%
df.to_csv('compact_schemes.csv')
