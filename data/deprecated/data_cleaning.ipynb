# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('D:\Projects\scheme-setu\data\schemes_cleaned.csv')

# %%
df.head(5)
# Out:
#            scheme_id                                        scheme_name  \
# 0       ira-wrflsncs  Immediate Relief Assistance" under "Welfare an...
# 1             astpss  AICTE SHORT TERM TRAINING PROGRAMME-SFURTI SCHEME
# 2  baepsicodouldwact  Burial and Ex-gratia Payment Scheme in Case of...
# 3               ctms                Consortia & Tender Marketing Scheme
# 4               gsfe                  Garuda Scheme for Funeral Expense
#
#                                          description  \
# 0  The scheme "Immediate Relief Assistance" is a ...
# 1  Short Term Training Programme-SFURTI Program, ...
# 2  Launched in 2014, the " Burial and Ex-gratia P...
# 3  Promotion of the product of Micro and Small En...
# 4  Andhra Pradesh Brahmin Welfare Corporation (AB...
#
#                                             benefits  \
# 0  ₹ 1,00,000, in two installments of ₹ 50,000 ea...
# 1  Financial Assistance : Limit of funding ₹ 4,00...
# ...

# %%
df[''][0]
# Out:
# '18+'

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3397 entries, 0 to 3396
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   scheme_id                3397 non-null   str
#  1   scheme_name              3397 non-null   str
#  2   description              3397 non-null   str
#  3   benefits                 3397 non-null   str
#  4   eligibility              3397 non-null   str
#  5   application_process      3393 non-null   str
#  6   required_documents       3384 non-null   str
#  7   government_level         3397 non-null   str
#  8   scheme_category          3397 non-null   str
#  9   scheme_category_list     3397 non-null   str
#  10  scheme_category_primary  3397 non-null   str
#  11  tags                     3368 non-null   str
#  12  tags_list                3397 non-null   str
#  13  target_gender            2530 non-null   str
#  14  target_category          2566 non-null   str
# ...

# %%
df_raw = pd.read_csv(r'D:\Projects\scheme-setu\data\raw_schemes.csv')

# %%
df_raw.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3400 entries, 0 to 3399
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   scheme_name     3400 non-null   str
#  1   slug            3400 non-null   str
#  2   details         3400 non-null   str
#  3   benefits        3400 non-null   str
#  4   eligibility     3400 non-null   str
#  5   application     3398 non-null   str
#  6   documents       3389 non-null   str
#  7   level           3400 non-null   str
#  8   schemeCategory  3400 non-null   str
#  9   tags            3371 non-null   str
# dtypes: str(10)
# memory usage: 265.8 KB
